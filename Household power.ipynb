# %% [markdown]
# # Read data

# %%
import pandas as pd

# %%
df = pd.read_csv("household_power_consumption.txt", sep=';', low_memory=False)

# %%
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
# add sub metering remainder
data_dictionary = df.values.tolist()

# %%
# Out:
# [['16/12/2006',
#   '17:24:00',
#   '4.216',
#   '0.418',
#   '234.840',
#   '18.400',
#   '0.000',
#   '1.000',
#   17.0],
#  ['16/12/2006',
#   '17:25:00',
#   '5.360',
#   '0.436',
#   '233.630',
#   '23.000',
#   '0.000',
#   '1.000',
#   16.0],
#  ['16/12/2006',
#   '17:26:00',
#   '5.374',
#   '0.498',
#   '233.290',
#   '23.000',
#   '0.000',
#   '2.000',
#   17.0],
#  ['16/12/2006',
#   '17:27:00',
#   '5.388',
#   '0.502',
#   '233.740',
#   '23.000',
#   '0.000',
#   '1.000',
#   17.0],
#  ['16/12/2006',
#   '17:28:00',
#   '3.666',
#   '0.528',
#   '235.680',
#   '15.800',
#   '0.000',
#   '1.000',
#   17.0],
#  ['16/12/2006',
#   '17:29:00',
#   '3.520',
#   '0.522',
#   '235.020',
#   '15.000',
#   '0.000',
#   '2.000',
#   17.0],
#  ['16/12/2006',
#   '17:30:00',
#   '3.702',
#   '0.520',
#   '235.090',
#   '15.800',
#   '0.000',
#   '1.000',
#   17.0],
#  ['16/12/2006',
#   '17:31:00',
#   '3.700',
#   '0.520',
#   '235.220',
#   '15.800',
#   '0.000',
#   '1.000',
# ...
